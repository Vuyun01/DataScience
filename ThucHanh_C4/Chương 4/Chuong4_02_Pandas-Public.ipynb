# %% [markdown]
# <img src ='pic/Logo_CNTT_png.png' width='100px'>
#
# ## CHƯƠNG 04: MỘT SỐ THƯ VIỆN QUAN TRỌNG TRONG KHOA HỌC DỮ LIỆU - PHẦN 2
# ---
# * Giảng Viên: Đặng Văn Nam
# * Email: dangvannam@humg.edu.vn
#
# **NỘI DUNG BÀI HỌC:**
# 1. Giới thiệu Pandas
# 2. Tạo đối tượng cơ bản trong Pandas
# 3. Đọc dữ liệu từ file CSV, Text, Excel
# 4. Quan sát và truy xuất dữ liệu trong DataFrame
# 5. Replacing Values, Rename Columns
# 6. Lọc dữ liệu trong DataFrame
# 6. Xác định các tham số thống kê: Sum, Cumsum, Min, Max, Mean, Median, Std
# 8. Giá trị duy nhất (Unique)
# 9. Phát hiện và xử lý dữ liệu khuyết thiếu (missing values)
# 10. Phát hiện và xử lý dữ liệu ngoại lai (Outliers)

# %% [markdown]
# # 1) Giới thiệu
# ---
# **Pandas** là một thư viện mã nguồn mở được xây dựng dựa trên NumPy, sử dụng để thao tác và phân tích dữ liệu. Với Pandas chúng ta có thể:
# Xử lý tập dữ liệu khác nhau về định dạng: chuỗi thời gian, bảng không đồng nhất, ma trận dữ liệu
# * Import dữ liệu từ nhiều nguồn khác nhau như CSV, DB/SQL…
# * Xử lý vô số phép toán cho tập dữ liệu: subsetting, slicing, filtering, merging, groupBy, re-ordering, and re-shaping,..
# * Xử lý dữ liệu mất mát theo mong muốn.
# * Xử lý, phân tích dữ liệu tốt như mô hình hoá và thống kê.
# * Tích hợp tốt với các thư viện khác của python.
#
# https://pandas.pydata.org/

# %%
#Kiểm tra phiên bản của thư viện Pandas
import pandas as pd
print('Version Pandas: ',pd.__version__)

# %% [markdown]
# # 2) Làm việc với các đối tượng trong Pandas
# ---
# ## 2.1) Series
#
# **Series** là mảng một chiều (1D) giống như kiểu vector trong Numpy, hay như một cột của một bảng, nhưng nó bao gồm thêm một bảng đánh index.

# %%
#Khai báo sử dụng thư viện
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Tạo một đối tượng series
#index mặc định đánh số từ 0
data = pd.Series([2.8, 3, 4.44, 5])
data

# %%
#BAI NAY TEST
arr = np.array([23.5, 21, 32, 5.2, 62, 11.2, 34])
data_test = pd.Series(arr,
                     index=['a','b','c','d','e','f','g'])
print(data_test.values)
print(data_test.index)
print(data_test['g'])
print(data_test[5])
# Out:
# [23.5 21.  32.   5.2 62.  11.2 34. ]
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g'], dtype='object')
# 34.0
# 11.2

# %%
#Mỗi một đối tượng series bao gồm 2 thành phần
#1. Values
#2. index
print('Values:', data.values)
print('Indices:', data.index)

# %%
#Tạo một đối tượng series với index thiết lập
data = pd.Series([1.25, 2, 3.5, 4.75, 8.0],
                 index=['a', 'b', 'c', 'd','k'])
data

# %%
print('Values:', data.values)
print('Indices:', data.index)

# %%
#Truy cập tới một phần tử trong series thông qua index hoặc thứ tự
print('Phần tử có index = b:', data['b'])
print('Phần tử ở vị trí 1  :', data[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-91e6687a8298> in <module>
#       1 #Truy cập tới một phần tử trong series thông qua index hoặc thứ tự
# ----> 2 print('Phần tử có index = b:', data['b'])
#       3 print('Phần tử ở vị trí 1  :', data[1])
#
# NameError: name 'data' is not defined

# %%
#Tạo đối tượng series từ một biến kiểu Dictionary
#Chỉ số được tự động sắp xếp.
population_dict = {'California': 38332521,
                   'Texas': 26448193,
                   'New York': 19651127,
                   'Florida': 19552860,
                   'Illinois': 12882135}
population = pd.Series(population_dict,name='Population_USA')
population
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135
# Name: Population_USA, dtype: int64

# %%
#View tên của series
population.name

# %%
population['Florida']
# Out:
# 19552860

# %%
#BAI NAY TEST
dict_test = {'Ha Noi':8230001,
            'Hai Phong':3294209,
            'Bac Giang':5293912,
            'Thai Binh':4242314,
            'Da Nang':5882002,
            'Tp.HCM':12098822}

population_test = pd.Series(dict_test,name='Population')
print(type(population_test))
population_test
# Out:
# <class 'pandas.core.series.Series'>
# Ha Noi        8230001
# Hai Phong     3294209
# Bac Giang     5293912
# Thai Binh     4242314
# Da Nang       5882002
# Tp.HCM       12098822
# Name: Population, dtype: int64

# %%
#Chuyển đổi từ dữ liệu vector sang series
a_vector = np.array([8,12,9,0,7,11])

a_series = pd.Series(a_vector,dtype='float')
a_series
# Out:
# 0     8.0
# 1    12.0
# 2     9.0
# 3     0.0
# 4     7.0
# 5    11.0
# dtype: float64

# %%
#BAI NAY TEST
arr_test = np.array([5, 4, 8, 7, 8])
arr_pandas = pd.Series(arr_test ,dtype= np.float32,index=['a','b','c','d','e'])
arr_pandas

# %% [markdown]
# ## 1.2) DataFrame
# ---

# %%
#Tạo DataFrame từ các Series
area_dict = {'California': 423967, 
             'Texas': 695662, 
             'New York': 141297,
             'Florida': 170312, 
             'Illinois': 149995}
area = pd.Series(area_dict, name='Area_USA')
area
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# Name: Area_USA, dtype: int64

# %%
data_usa = pd.DataFrame({'population':population,
                         'area':area})
data_usa
# Out:
#             population    area
# California    38332521  423967
# Texas         26448193  695662
# New York      19651127  141297
# Florida       19552860  170312
# Illinois      12882135  149995

# %%
#BAI NAY TEST
area_diction = {'Ha Noi':20003,
            'Hai Phong':17232,
            'Bac Giang':15212,
            'Thai Binh':12314,
            'Da Nang':14002,
            'Tp.HCM':19822}
area_pandas = pd.Series(area_diction, name='Area')
data_vn = pd.DataFrame([population_test,
                       area_pandas])
data_vn

# %%
#Tương tự như series, DataFrame cũng có thuộc tính values và index
df_values = data_usa.values
df_index = data_usa.index
print('Values of DataFrame:\n',df_values)
print('Index of DataFrame:\n',df_index)

# %%
#Tạo một DataFrame từ một biến Dict
#Chỉ số được tạo mặc định từ 0
data_dict = {
    'apples': [3, 2, 0, 1], 
    'oranges': [0, 3, 7, 2]}

purchases = pd.DataFrame(data_dict)
purchases

# %%
#Tạo DataFrame với index thiết lập
purchases = pd.DataFrame(data_dict, 
                         index=['June', 'Robert', 'Lily', 'David'])
purchases

# %%
#BAI NAY TEST
dict_luong1 = {'January':21299990,
             'February':12930000,
             'March':15009000,
             'April':29900000}

dict_luong2 = {'January':19288390,
             'February':12890000,
             'March':1718000,
             'April':23800000}

dict_luong3 = {'January':11387720,
             'February':15320000,
             'March':18989000,
             'April':31708800}


luong_list1 = pd.Series(dict_luong1,name='Bang Luong 1')
luong_list2 = pd.Series(dict_luong2,name='Bang Luong 2')
luong_list3 = pd.Series(dict_luong3,name='Bang Luong 3')


df_luong = pd.DataFrame({'Vu':luong_list1,
                        'Anh':luong_list2,
                        'Phuong':luong_list3})

# df_luong = pd.DataFrame([luong_list1, luong_list2, luong_list3],index=['Vu','Anh','Phuong'])


print(df_luong.index)

df_luong
# Out:
# Index(['January', 'February', 'March', 'April'], dtype='object')
#                 Vu       Anh    Phuong
# January   21299990  19288390  11387720
# February  12930000  12890000  15320000
# March     15009000   1718000  18989000
# April     29900000  23800000  31708800

# %%
dict_arr = {'Name':['Thu', 'An', 'Hung', 'Hoang', 'Nga', 'Khai'],
           'Age':[19, 20, 20, 19, 23, 21]}


df_arr = pd.DataFrame(dict_arr, index=['a','b','c','d','e','f'])

df_arr
# Out:
#     Name  Age
# a    Thu   19
# b     An   20
# c   Hung   20
# d  Hoang   19
# e    Nga   23
# f   Khai   21

# %%
arr = [19, 20, 20, 19, 23, 21]
arr1 = pd.Series(arr, name ='Age', index=['a','b','c','d','e','f'])

df_arr = pd.DataFrame(arr1)

df_arr['Age']
# Out:
# a    19
# b    20
# c    20
# d    19
# e    23
# f    21
# Name: Age, dtype: int64

# %% [markdown]
# # 3) Đọc dữ liệu từ các nguồn khác nhau (CSV, Text, Excel)
# ---
# ## 3.1) Đọc file CSV
# * CSV là một định dạng dữ liệu văn bản đơn giản có tên đầy đủ là Comma Separated Values. Với định dạng CSV này, các giá trị được chia tách với nhau bởi các dấu phẩy. Định dạng CSV phổ biến bởi vì chúng có tính tương thích cao, dễ dàng di chuyển từ phần mềm này sang phần mềm khác để sử dụng mà không lo gặp các xung đột.
#
# * Tài liệu CSV cũng làm một trong những tài liệu phổ biến trên thế giới với khả năng lưu trữ nhỏ nhẹ.

# %%
import pandas as pd
path = 'Data_Excercise\csv_Data_BMI.csv'
#Sử dụng phương thức read_csv
data = pd.read_csv(path)
#Hiển thị thông tin biến Data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Personal   500 non-null    object
#  1   Gender     500 non-null    object
#  2   Height_cm  500 non-null    int64
#  3   Weight_kg  500 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 15.8+ KB

# %%
data
# print(type(data))
# Out:
#     Personal  Gender  Height_cm  Weight_kg
# 0         P1    Male        174         96
# 1         P2    Male        189         87
# 2         P3  Female        185        110
# 3         P4  Female        195        104
# 4         P5    Male        149         61
# ..       ...     ...        ...        ...
# 495     P496  Female        150        153
# 496     P497  Female        184        121
# 497     P498  Female        141        136
# 498     P499    Male        150         95
# 499     P500    Male        173        131
#
# [500 rows x 4 columns]

# %%
#VÍ DỤ 1:
#Sử dụng phương thức read_csv()
#Tham số: Thiết lập cột index là cột Personal
data1 = pd.read_csv(path,
                    index_col=0)
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, P1 to P500
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Gender     500 non-null    object
#  1   Height_cm  500 non-null    int64
#  2   Weight_kg  500 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 15.6+ KB

# %%
data1.head()
# Out:
#           Gender  Height_cm  Weight_kg
# Personal
# P1          Male        174         96
# P2          Male        189         87
# P3        Female        185        110
# P4        Female        195        104
# P5          Male        149         61

# %%
#VÍ DỤ 2:
#Sử dụng phương thức read_csv()
#Thiết lập số hàng, cột muốn đọc dữ liệu
data2 = pd.read_csv(path,
                    nrows=100,
                    usecols=['Height_cm', 'Weight_kg'])
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Height_cm  100 non-null    int64
#  1   Weight_kg  100 non-null    int64
# dtypes: int64(2)
# memory usage: 1.7 KB

# %%
data2.tail()
# Out:
#     Height_cm  Weight_kg
# 95        170        156
# 96        142         69
# 97        160        139
# 98        195         69
# 99        190         50

# %%
#VÍ DỤ 3:
#Thiết lập tham số đọc dữ liệu từ dòng thứ 5 trong file
#và đặt lại tên của các cột dữ liệu
data3 = pd.read_csv(path,
                    names=['ID','Sex','H(cm)','W(kg)'],
                    skiprows=5)
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 496 entries, 0 to 495
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      496 non-null    object
#  1   Sex     496 non-null    object
#  2   H(cm)   496 non-null    int64
#  3   W(kg)   496 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 15.6+ KB

# %%
data3.head()
# Out:
#    ID   Sex  H(cm)  W(kg)
# 0  P5  Male    149     61
# 1  P6  Male    189    104
# 2  P7  Male    147     92
# 3  P8  Male    154    111
# 4  P9  Male    174     90

# %% [markdown]
# #### Load data from .txt
# ---

# %%
#Đọc dữ liệu trong file Diamonds.txt:
df_Diamonds = pd.read_csv('Data_Excercise/Diamonds.txt',
                     names=['Weight(carat)','Price(USD)'],
                     sep='\t', #mặc định sep=','
                     header = None)
                    
df_Diamonds
# Out:
#     Weight(carat)  Price(USD)
# 0            0.23         484
# 1            0.31         942
# 2            0.20         345
# 3            1.02        4459
# 4            1.63       14022
# 5            1.14        4212
# 6            2.01       11925
# 7            1.28        9548
# 8            1.70       11605
# 9            1.01        4642
# 10           0.64        3541
# 11           0.97        4504
# 12           1.78       13691
# 13           3.40       15964
# 14           3.01       10453
# 15           1.51       11560
# 16           1.37        7979
# 17           1.50        9533
# 18           0.54        1723
# 19           0.72        3344
# 20           1.13        6133
# 21           2.24       13827
# 22           3.01       16538
# 23           4.50       18531
# 24           0.92        3625
# 25           1.05        7879
# 26           0.55        1319
# 27           0.74        2761
# 28           0.91        3620
# 29           1.23        6165
# 30           1.52       10640
# 31           0.91        4138
# 32           0.43        1094
# 33           1.24       11130
# 34           1.77       14561
# 35           1.79       10108
# 36           2.05       12654
# 37           2.03       16280
# 38           2.01       13498
# 39           1.00        4586
# 40           0.90        3105
# 41           1.01        7745
# 42           1.14        5047
# 43           1.53       10830
# 44           0.34         765
# 45           0.41         827
# 46           0.75        3120
# 47           1.07        5220
# 48           1.34        7427
# 49           1.75        9890

# %%
import matplotlib.pyplot as plt
df_Diamonds.plot.scatter(x='Weight(carat)',y='Price(USD)',color='red')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Bài tập 22:
# ---

# %% [markdown]
# ## Đọc file Excel
# ---

# %%
import pandas as pd
path_excel = 'Data_Excercise\excel_Data_Point.xlsx'
#Đọc dữ liệu từ file excel
data_ex = pd.read_excel(path_excel)
data_ex.info()
data_ex
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   STT        66 non-null     int64
#  1   Mã SV      66 non-null     int64
#  2   Họ         66 non-null     object
#  3   Tên        66 non-null     object
#  4   Ngày sinh  66 non-null     object
#  5   Tên Lớp    66 non-null     object
#  6   A          66 non-null     float64
#  7   B1         66 non-null     float64
#  8   B2         66 non-null     float64
#  9   C1         66 non-null     float64
#  10  C2         66 non-null     float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 5.8+ KB
#     STT       Mã SV                Họ   Tên   Ngày sinh     Tên Lớp    A   B1  \
# 0     1  1621050322       Phạm Trường    An  04/10/1998  DCCTPM61_1  8.0  0.0
# 1     2  1621050512  Nguyễn Quang Duy   Anh  08/10/1998  DCCTPM61_1  6.0  3.0
# 2     3  1621050211        Nguyễn Thế   Anh  26/08/1998  DCCTPM61_1  6.7  4.0
# 3     4  1621050827           Đỗ Xuân  Bách  13/07/1998  DCCTPM61_1  8.0  6.5
# 4     5  1621050298         Dương Trí  Bách  25/09/1998  DCCTPM61_1  7.0  5.0
# ..  ...         ...               ...   ...         ...         ...  ...  ...
# 61   62  1621050069         Nguyễn Đỗ  Thật  08/02/1998  DCCTPM61_1  6.0  7.0
# 62   63  1621050337        Nguyễn Đức   Thu  27/11/1994  DCCTPM61_1  6.7  6.0
# 63   64  1621050756     Đặng Thị Ngọc  Thùy  25/01/1998  DCCTPM61_1  6.7  3.0
# 64   65  1621050053          Phạm Gia  Thức  09/07/1998  DCCTPM61_1  7.7  9.0
# 65   66  1621050013           Đỗ Hồng  Tiến  09/02/1998  DCCTPM61_1  6.7  7.5
#
#      B2    C1    C2
# 0   5.0   7.5   8.0
# 1   7.5   8.5   9.0
# 2   6.5   3.0   5.0
# 3   8.0  10.0   9.0
# 4   8.0   8.5   9.0
# ..  ...   ...   ...
# 61  9.0  10.0   8.5
# 62  7.5   3.0   4.0
# 63  7.0   9.5   9.0
# 64  5.0  10.0   9.5
# 65  8.0  10.0  10.0
#
# [66 rows x 11 columns]

# %%
#VÍ DỤ 1:
#Đọc dữ liệu tại sheet đầu tiên, 
#Chỉ lấy dữ liệu cột Mã SV và các cột điểm 
#Thiết lập cột đầu tiên làm index
data_ex1 = pd.read_excel(path_excel,
                        sheet_name='4080130_01',
                        usecols=[1,6,7,8,9,10],
                        index_col=0)
data_ex1.info()
data_ex1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66 entries, 1621050322 to 1621050013
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       66 non-null     float64
#  1   B1      66 non-null     float64
#  2   B2      66 non-null     float64
#  3   C1      66 non-null     float64
#  4   C2      66 non-null     float64
# dtypes: float64(5)
# memory usage: 3.1 KB
#               A   B1   B2    C1    C2
# Mã SV
# 1621050322  8.0  0.0  5.0   7.5   8.0
# 1621050512  6.0  3.0  7.5   8.5   9.0
# 1621050211  6.7  4.0  6.5   3.0   5.0
# 1621050827  8.0  6.5  8.0  10.0   9.0
# 1621050298  7.0  5.0  8.0   8.5   9.0
# ...         ...  ...  ...   ...   ...
# 1621050069  6.0  7.0  9.0  10.0   8.5
# 1621050337  6.7  6.0  7.5   3.0   4.0
# 1621050756  6.7  3.0  7.0   9.5   9.0
# 1621050053  7.7  9.0  5.0  10.0   9.5
# 1621050013  6.7  7.5  8.0  10.0  10.0
#
# [66 rows x 5 columns]

# %%
data_ex1.head()
# Out:
#               A   B1   B2    C1   C2
# Mã SV
# 1621050322  8.0  0.0  5.0   7.5  8.0
# 1621050512  6.0  3.0  7.5   8.5  9.0
# 1621050211  6.7  4.0  6.5   3.0  5.0
# 1621050827  8.0  6.5  8.0  10.0  9.0
# 1621050298  7.0  5.0  8.0   8.5  9.0

# %%
#VÍ DỤ 2:
#Đọc dữ liệu tại sheet 2, 
#Trường hợp: sử dụng các tham số mặc định
data_ex2 = pd.read_excel(path_excel,
                        sheet_name=1)
data_ex2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 11 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Cộng Hòa Xã Hội Chủ Nghĩa Việt Nam  45 non-null     object
#  1   Unnamed: 1                          40 non-null     object
#  2   Unnamed: 2                          40 non-null     object
#  3   Unnamed: 3                          40 non-null     object
#  4   Unnamed: 4                          42 non-null     object
#  5   Unnamed: 5                          40 non-null     object
#  6   Unnamed: 6                          40 non-null     object
#  7   Unnamed: 7                          40 non-null     object
#  8   Unnamed: 8                          40 non-null     object
#  9   Unnamed: 9                          40 non-null     object
#  10  Unnamed: 10                         40 non-null     object
# dtypes: object(11)
# memory usage: 4.2+ KB

# %%
data_ex2.head(10)

# %%
#VÍ DỤ 3:
#Đọc dữ liệu tại sheet '4080130_02',từ dòng 9
data_ex3 = pd.read_excel(path_excel,
                         sheet_name='4080130_02',
                         skiprows=9)
data_ex3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   STT        39 non-null     int64
#  1   Mã SV      39 non-null     int64
#  2   Họ         39 non-null     object
#  3   Tên        39 non-null     object
#  4   Ngày sinh  39 non-null     object
#  5   Tên Lớp    39 non-null     object
#  6   A          39 non-null     float64
#  7   B1         39 non-null     float64
#  8   B2         39 non-null     float64
#  9   C1         39 non-null     float64
#  10  C2         39 non-null     float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 3.5+ KB

# %%
data_ex3.head()
# Out:
#    STT       Mã SV          Họ  Tên   Ngày sinh     Tên Lớp    A   B1   B2  \
# 0    1  1621050193   Đặng Đình   An  15/02/1998  DCCTPM61_1  7.0  6.5  7.5
# 1    2  1621070195    Mai Việt  Anh  01/09/1998   DCCTPM62A  8.0  6.5  6.0
# 2    3  1721050524  Nguyễn Thị  Anh  18/05/1999   DCCTPM62A  7.7  6.0  7.5
# 3    4  1621050484   Phạm Tuấn  Anh  27/10/1998  DCCTPM61_1  6.3  3.0  5.0
# 4    5  1621050260   Phan Tuấn  Anh  20/05/1998  DCCTPM61_1  7.7  6.5  7.0
#
#      C1   C2
# 0   7.0  8.0
# 1   5.0  6.0
# 2   8.5  9.0
# 3   0.0  5.0
# 4  10.0  9.0

# %%
#Ví dụ 4
#Đọc dữ liệu từ sheet: '4080130_03'
#Dữ liệu không chứa dòng header
data_ex4 = pd.read_excel(path_excel,
                         sheet_name=2,
                         header=None)
data_ex4.head()
# Out:
#    0           1           2      3           4           5    6    7    8   \
# 0   1  1621050041    Đào Tuấn    Anh  22/10/1998  DCCTPM61_1  6.7  9.0  5.5
# 1   2  1621050262  Vũ Thị Lan    Anh  26/09/1998  DCCTPM61_1  6.7  7.0  9.0
# 2   3  1621050083   Trịnh Như   Bình  06/04/1998  DCCTPM61_1  7.3  8.5  9.5
# 3   4  1621050113    Trần Văn  Cương  19/06/1998  DCCTPM61_1  5.7  5.0  6.0
# 4   5  1621050384   Nguyễn Sỹ   Dũng  02/10/1998  DCCTPM61_1  7.0  0.0  7.5
#
#      9    10
# 0   8.5  8.0
# 1   8.5  6.0
# 2  10.0  9.0
# 3  10.0  5.0
# 4   8.5  9.0

# %%
#Ví dụ 4.1
#Đọc dữ liệu từ sheet: '4080130_03'
#Dữ liệu không chứa dòng header
#Đặt tên cho các cột
data_ex41 = pd.read_excel(path_excel,
                        sheet_name='4080130_03',
                        header=None,
                        usecols=[1,6,7,8,9,10],
                        names=['Mã SV','A','B1','B2','C1','C2'],
                        index_col=0)
data_ex41.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-4e739120754c> in <module>
#       3 #Dữ liệu không chứa dòng header
#       4 #Đặt tên cho các cột
# ----> 5 data_ex41 = pd.read_excel(path_excel,
#       6                         sheet_name='4080130_03',
#       7                         header=None,
#
# NameError: name 'path_excel' is not defined

# %%
data_ex41.head()
# Out:
#               A   B1   B2    C1   C2
# Mã SV
# 1621050041  6.7  9.0  5.5   8.5  8.0
# 1621050262  6.7  7.0  9.0   8.5  6.0
# 1621050083  7.3  8.5  9.5  10.0  9.0
# 1621050113  5.7  5.0  6.0  10.0  5.0
# 1621050384  7.0  0.0  7.5   8.5  9.0

# %% [markdown]
# ## Bài tập 23:
# ---

# %% [markdown]
# # 3) Quan sát và truy suất dữ liệu từ DataFrame
# ---
# ## 3.1) Quan sát dữ liệu

# %%
#Đọc dữ liệu mẫu được lưu trữ trong file csv
path='Data_Excercise\csv_Data_Loan.csv'
df_loan=pd.read_csv(path)
df_loan
# Out:
#         loan_amnt       term  int_rate  emp_length home_ownership  annual_inc  \
# 0            5000  36 months     10.65        10.0           RENT     24000.0
# 1            2500  60 months     15.27         0.0           RENT     30000.0
# 2            2400  36 months     15.96        10.0           RENT     12252.0
# 3           10000  36 months     13.49        10.0           RENT     49200.0
# 4            5000  36 months      7.90         3.0           RENT     36000.0
# ...           ...        ...       ...         ...            ...         ...
# 163982      15000  60 months     12.39         3.0       MORTGAGE     45000.0
# 163983      20000  36 months     14.99        10.0            OWN     80000.0
# 163984      12825  36 months     17.14         6.0       MORTGAGE     38000.0
# 163985      27650  60 months     21.99         0.0           RENT     60000.0
# 163986      17000  60 months     15.99        10.0       MORTGAGE     63078.0
#
#                    purpose addr_state    dti  delinq_2yrs  revol_util  \
# 0              credit_card         AZ  27.65          0.0        83.7
# 1                      car         GA   1.00          0.0         9.4
# 2           small_business         IL   8.72          0.0        98.5
# 3                    other         CA  20.00          0.0        21.0
# 4                  wedding         AZ  11.20          0.0        28.3
# ...                    ...        ...    ...          ...         ...
# 163982         credit_card         OK  31.44          4.0        75.8
# 163983    home_improvement         VA  23.65          0.0        68.8
# 163984  debt_consolidation         TX   9.03          0.0        70.7
# 163985         credit_card         NY  10.10          1.0        61.2
# 163986  debt_consolidation         PA  31.70          0.0        54.0
#
#         total_acc  bad_loan  longest_credit_length verification_status
# 0             9.0         0                   26.0            verified
# 1             4.0         1                   12.0            verified
# 2            10.0         0                   10.0        not verified
# 3            37.0         0                   15.0            verified
# 4            12.0         0                    7.0            verified
# ...           ...       ...                    ...                 ...
# 163982       34.0         0                   20.0        not verified
# 163983       18.0         0                   22.0            verified
# 163984       24.0         0                    9.0        not verified
# 163985       20.0         0                    6.0            verified
# 163986       28.0         0                   16.0            verified
#
# [163987 rows x 15 columns]

# %%
#Quan sát dữ liệu biến DataFrame
df_loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163987 entries, 0 to 163986
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   loan_amnt              163987 non-null  int64
#  1   term                   163987 non-null  object
#  2   int_rate               163987 non-null  float64
#  3   emp_length             158183 non-null  float64
#  4   home_ownership         163987 non-null  object
#  5   annual_inc             163983 non-null  float64
#  6   purpose                163987 non-null  object
#  7   addr_state             163987 non-null  object
#  8   dti                    163987 non-null  float64
#  9   delinq_2yrs            163958 non-null  float64
#  10  revol_util             163794 non-null  float64
#  11  total_acc              163958 non-null  float64
#  12  bad_loan               163987 non-null  int64
#  13  longest_credit_length  163958 non-null  float64
#  14  verification_status    163987 non-null  object
# dtypes: float64(8), int64(2), object(5)
# memory usage: 18.8+ MB

# %%
#Hiển thị 10 dòng đầu tiên
df_loan.head(12)
# Out:
#     loan_amnt       term  int_rate  emp_length home_ownership  annual_inc  \
# 0        5000  36 months     10.65        10.0           RENT     24000.0
# 1        2500  60 months     15.27         0.0           RENT     30000.0
# 2        2400  36 months     15.96        10.0           RENT     12252.0
# 3       10000  36 months     13.49        10.0           RENT     49200.0
# 4        5000  36 months      7.90         3.0           RENT     36000.0
# 5        3000  36 months     18.64         9.0           RENT     48000.0
# 6        5600  60 months     21.28         4.0            OWN     40000.0
# 7        5375  60 months     12.69         0.0           RENT     15000.0
# 8        6500  60 months     14.65         5.0            OWN     72000.0
# 9       12000  36 months     12.69        10.0            OWN     75000.0
# 10       9000  36 months     13.49         0.0           RENT     30000.0
# 11       3000  36 months      9.91         3.0           RENT     15000.0
#
#                purpose addr_state    dti  delinq_2yrs  revol_util  total_acc  \
# 0          credit_card         AZ  27.65          0.0        83.7        9.0
# 1                  car         GA   1.00          0.0         9.4        4.0
# 2       small_business         IL   8.72          0.0        98.5       10.0
# 3                other         CA  20.00          0.0        21.0       37.0
# 4              wedding         AZ  11.20          0.0        28.3       12.0
# 5                  car         CA   5.35          0.0        87.5        4.0
# 6       small_business         CA   5.55          0.0        32.6       13.0
# 7                other         TX  18.08          0.0        36.5        3.0
# 8   debt_consolidation         AZ  16.12          0.0        20.6       23.0
# 9   debt_consolidation         CA  10.78          0.0        67.1       34.0
# 10  debt_consolidation         VA  10.08          0.0        91.7        9.0
# 11         credit_card         IL  12.56          0.0        43.1       11.0
#
#     bad_loan  longest_credit_length verification_status
# 0          0                   26.0            verified
# 1          1                   12.0            verified
# 2          0                   10.0        not verified
# 3          0                   15.0            verified
# 4          0                    7.0            verified
# 5          0                    4.0            verified
# 6          1                    7.0            verified
# 7          1                    7.0            verified
# 8          0                   13.0        not verified
# 9          0                   22.0            verified
# 10         1                    7.0            verified
# 11         0                    8.0            verified

# %%
#Hiển thị 5 dòng cuối cùng của biến df_loan
df_loan.tail()
# Out:
#         loan_amnt       term  int_rate  emp_length home_ownership  annual_inc  \
# 163982      15000  60 months     12.39         3.0       MORTGAGE     45000.0
# 163983      20000  36 months     14.99        10.0            OWN     80000.0
# 163984      12825  36 months     17.14         6.0       MORTGAGE     38000.0
# 163985      27650  60 months     21.99         0.0           RENT     60000.0
# 163986      17000  60 months     15.99        10.0       MORTGAGE     63078.0
#
#                    purpose addr_state    dti  delinq_2yrs  revol_util  \
# 163982         credit_card         OK  31.44          4.0        75.8
# 163983    home_improvement         VA  23.65          0.0        68.8
# 163984  debt_consolidation         TX   9.03          0.0        70.7
# 163985         credit_card         NY  10.10          1.0        61.2
# 163986  debt_consolidation         PA  31.70          0.0        54.0
#
#         total_acc  bad_loan  longest_credit_length verification_status
# 163982       34.0         0                   20.0        not verified
# 163983       18.0         0                   22.0            verified
# 163984       24.0         0                    9.0        not verified
# 163985       20.0         0                    6.0            verified
# 163986       28.0         0                   16.0            verified

# %%
#Hiển thị kích thước df_loan (rows x columns)
df_loan.shape
# Out:
# (163987, 15)

# %%
#Danh sách tên các columns trong df
df_loan.columns
# Out:
# Index(['loan_amnt', 'term', 'int_rate', 'emp_length', 'home_ownership',
#        'annual_inc', 'purpose', 'addr_state', 'dti', 'delinq_2yrs',
#        'revol_util', 'total_acc', 'bad_loan', 'longest_credit_length',
#        'verification_status'],
#       dtype='object')

# %%
#BAI NAY TEST
path_2 = 'Data_Excercise\csv_Data_BMI.csv'
df_bmi = pd.read_csv(path_2)

df_bmi
# Out:
#     Personal  Gender  Height_cm  Weight_kg
# 0         P1    Male        174         96
# 1         P2    Male        189         87
# 2         P3  Female        185        110
# 3         P4  Female        195        104
# 4         P5    Male        149         61
# ..       ...     ...        ...        ...
# 495     P496  Female        150        153
# 496     P497  Female        184        121
# 497     P498  Female        141        136
# 498     P499    Male        150         95
# 499     P500    Male        173        131
#
# [500 rows x 4 columns]

# %%
#Kiếm tra giá trị null trong Df
df_loan.isnull()
# Out:
#         loan_amnt   term  int_rate  emp_length  home_ownership  annual_inc  \
# 0           False  False     False       False           False       False
# 1           False  False     False       False           False       False
# 2           False  False     False       False           False       False
# 3           False  False     False       False           False       False
# 4           False  False     False       False           False       False
# ...           ...    ...       ...         ...             ...         ...
# 163982      False  False     False       False           False       False
# 163983      False  False     False       False           False       False
# 163984      False  False     False       False           False       False
# 163985      False  False     False       False           False       False
# 163986      False  False     False       False           False       False
#
#         purpose  addr_state    dti  delinq_2yrs  revol_util  total_acc  \
# 0         False       False  False        False       False      False
# 1         False       False  False        False       False      False
# 2         False       False  False        False       False      False
# 3         False       False  False        False       False      False
# 4         False       False  False        False       False      False
# ...         ...         ...    ...          ...         ...        ...
# 163982    False       False  False        False       False      False
# 163983    False       False  False        False       False      False
# 163984    False       False  False        False       False      False
# 163985    False       False  False        False       False      False
# 163986    False       False  False        False       False      False
#
#         bad_loan  longest_credit_length  verification_status
# 0          False                  False                False
# 1          False                  False                False
# 2          False                  False                False
# 3          False                  False                False
# 4          False                  False                False
# ...          ...                    ...                  ...
# 163982     False                  False                False
# 163983     False                  False                False
# 163984     False                  False                False
# 163985     False                  False                False
# 163986     False                  False                False
#
# [163987 rows x 15 columns]

# %%
#Thống kê số lượng null theo cột
df_loan.isnull().sum()
# Out:
# loan_amnt                   0
# term                        0
# int_rate                    0
# emp_length               5804
# home_ownership              0
# annual_inc                  4
# purpose                     0
# addr_state                  0
# dti                         0
# delinq_2yrs                29
# revol_util                193
# total_acc                  29
# bad_loan                    0
# longest_credit_length      29
# verification_status         0
# dtype: int64

# %%
#Cho biết số dòng dữ liệu không null
df_loan.count()
# Out:
# loan_amnt                163987
# term                     163987
# int_rate                 163987
# emp_length               158183
# home_ownership           163987
# annual_inc               163983
# purpose                  163987
# addr_state               163987
# dti                      163987
# delinq_2yrs              163958
# revol_util               163794
# total_acc                163958
# bad_loan                 163987
# longest_credit_length    163958
# verification_status      163987
# dtype: int64

# %%
#Số phần tử trong df (= rows x columns)
df_loan.size
# Out:
# 2459805

# %%
#Kiểu dữ liệu của từng columns trong df
df_loan.dtypes
# Out:
# loan_amnt                  int64
# term                      object
# int_rate                 float64
# emp_length               float64
# home_ownership            object
# annual_inc               float64
# purpose                   object
# addr_state                object
# dti                      float64
# delinq_2yrs              float64
# revol_util               float64
# total_acc                float64
# bad_loan                   int64
# longest_credit_length    float64
# verification_status       object
# dtype: object

# %%
#Quan sát một số đặc trưng thống kê của df
#Mặc định thống kê các cột dữ liệu số
df_loan.describe()
# Out:
#            loan_amnt       int_rate     emp_length    annual_inc  \
# count  163987.000000  163987.000000  158183.000000  1.639830e+05
# mean    13074.169141      13.715904       5.684353  7.191567e+04
# std      7993.556189       4.391940       3.610664  5.907092e+04
# min       500.000000       5.420000       0.000000  1.896000e+03
# 25%      7000.000000      10.650000       2.000000  4.500000e+04
# 50%     11325.000000      13.490000       6.000000  6.100000e+04
# 75%     18000.000000      16.320000      10.000000  8.500000e+04
# max     35000.000000      26.060000      10.000000  7.141778e+06
#
#                  dti    delinq_2yrs     revol_util      total_acc  \
# count  163987.000000  163958.000000  163794.000000  163958.000000
# mean       15.881530       0.227357      54.079173      24.579734
# std         7.587668       0.694168      25.285367      11.685190
# min         0.000000       0.000000       0.000000       1.000000
# 25%        10.230000       0.000000      35.600000      16.000000
# 50%        15.620000       0.000000      55.800000      23.000000
# 75%        21.260000       0.000000      74.200000      31.000000
# max        39.990000      29.000000     150.700000     118.000000
#
#             bad_loan  longest_credit_length
# count  163987.000000          163958.000000
# mean        0.183039              14.854274
# std         0.386700               6.947733
# min         0.000000               0.000000
# 25%         0.000000              10.000000
# 50%         0.000000              14.000000
# 75%         0.000000              18.000000
# max         1.000000              65.000000

# %%
df_loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163987 entries, 0 to 163986
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   loan_amnt              163987 non-null  int64
#  1   term                   163987 non-null  object
#  2   int_rate               163987 non-null  float64
#  3   emp_length             158183 non-null  float64
#  4   home_ownership         163987 non-null  object
#  5   annual_inc             163983 non-null  float64
#  6   purpose                163987 non-null  object
#  7   addr_state             163987 non-null  object
#  8   dti                    163987 non-null  float64
#  9   delinq_2yrs            163958 non-null  float64
#  10  revol_util             163794 non-null  float64
#  11  total_acc              163958 non-null  float64
#  12  bad_loan               163987 non-null  int64
#  13  longest_credit_length  163958 non-null  float64
#  14  verification_status    163987 non-null  object
# dtypes: float64(8), int64(2), object(5)
# memory usage: 18.8+ MB

# %%
df_loan.head(10)

# %%
#Quan sát một số đặc trưng thống kê của df
#Thống kê các cột dữ liệu Object
df_loan.describe(include='O')
# Out:
#              term home_ownership             purpose addr_state  \
# count      163987         163987              163987     163987
# unique          2              6                  14         50
# top     36 months       MORTGAGE  debt_consolidation         CA
# freq       129950          79714               93261      28702
#
#        verification_status
# count               163987
# unique                   2
# top               verified
# freq                104832

# %%
#Thống kê tất cả các cột dữ liệu ko phân biệt số, object
df_loan.describe(include='all')
# Out:
#             loan_amnt       term       int_rate     emp_length home_ownership  \
# count   163987.000000     163987  163987.000000  158183.000000         163987
# unique            NaN          2            NaN            NaN              6
# top               NaN  36 months            NaN            NaN       MORTGAGE
# freq              NaN     129950            NaN            NaN          79714
# mean     13074.169141        NaN      13.715904       5.684353            NaN
# std       7993.556189        NaN       4.391940       3.610664            NaN
# min        500.000000        NaN       5.420000       0.000000            NaN
# 25%       7000.000000        NaN      10.650000       2.000000            NaN
# 50%      11325.000000        NaN      13.490000       6.000000            NaN
# 75%      18000.000000        NaN      16.320000      10.000000            NaN
# max      35000.000000        NaN      26.060000      10.000000            NaN
#
#           annual_inc             purpose addr_state            dti  \
# count   1.639830e+05              163987     163987  163987.000000
# unique           NaN                  14         50            NaN
# top              NaN  debt_consolidation         CA            NaN
# freq             NaN               93261      28702            NaN
# mean    7.191567e+04                 NaN        NaN      15.881530
# std     5.907092e+04                 NaN        NaN       7.587668
# min     1.896000e+03                 NaN        NaN       0.000000
# 25%     4.500000e+04                 NaN        NaN      10.230000
# 50%     6.100000e+04                 NaN        NaN      15.620000
# 75%     8.500000e+04                 NaN        NaN      21.260000
# max     7.141778e+06                 NaN        NaN      39.990000
#
#           delinq_2yrs     revol_util      total_acc       bad_loan  \
# count   163958.000000  163794.000000  163958.000000  163987.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean         0.227357      54.079173      24.579734       0.183039
# std          0.694168      25.285367      11.685190       0.386700
# min          0.000000       0.000000       1.000000       0.000000
# 25%          0.000000      35.600000      16.000000       0.000000
# 50%          0.000000      55.800000      23.000000       0.000000
# 75%          0.000000      74.200000      31.000000       0.000000
# max         29.000000     150.700000     118.000000       1.000000
#
#         longest_credit_length verification_status
# count           163958.000000              163987
# unique                    NaN                   2
# top                       NaN            verified
# freq                      NaN              104832
# mean                14.854274                 NaN
# std                  6.947733                 NaN
# min                  0.000000                 NaN
# 25%                 10.000000                 NaN
# 50%                 14.000000                 NaN
# 75%                 18.000000                 NaN
# max                 65.000000                 NaN

# %%
#Quan sát đặc trưng thống kê theo từng cột
#Dữ liệu số
df_loan[['loan_amnt']].describe()
# Out:
#            loan_amnt
# count  163987.000000
# mean    13074.169141
# std      7993.556189
# min       500.000000
# 25%      7000.000000
# 50%     11325.000000
# 75%     18000.000000
# max     35000.000000

# %%
#Quan sát đặc trưng thống kê theo từng cột
#Dữ liệu Object
df_loan[['term']].describe()
# Out:
#              term
# count      163987
# unique          2
# top     36 months
# freq       129950

# %% [markdown]
# ## 3.2) Truy xuất dữ liệu trong DataFrame
# ---

# %%
#Truy xuất dữ liệu theo cột
#Lấy dữ liệu của một cột
df_state = df_loan[['addr_state']]
df_state.head()
# Out:
#   addr_state
# 0         AZ
# 1         GA
# 2         IL
# 3         CA
# 4         AZ

# %%
#BAI NAY TEST
df_test = df_loan[['term']]
df_test.tail()
# Out:
#              term
# 163982  60 months
# 163983  36 months
# 163984  36 months
# 163985  60 months
# 163986  60 months

# %%
#Truy xuất dữ liệu theo cột
#Chỉ lấy dữ liệu của 3 cột: loan_amnt, int_rate, purpose
df_loan1 = df_loan[['loan_amnt','int_rate','purpose']]
df_loan1.head()
# Out:
#    loan_amnt  int_rate         purpose
# 0       5000     10.65     credit_card
# 1       2500     15.27             car
# 2       2400     15.96  small_business
# 3      10000     13.49           other
# 4       5000      7.90         wedding

# %% [markdown]
# #### df.iloc[[index_row],[index_col]]: Truy cập tới dữ liệu của hàng và cột qua chỉ số index_row, index_col (tương tự như với Numpy)

# %%
#Sử dụng .iloc truy xuất dữ liệu như với Numpy
#Truy xuất 10 dòng dữ liệu từ [10 --> 20) tất cả các cột --- index = 0
df_loan.iloc[10:20,2:5]
# Out:
#     int_rate  emp_length home_ownership
# 10     13.49         0.0           RENT
# 11      9.91         3.0           RENT
# 12     10.65         3.0           RENT
# 13     16.29         0.0           RENT
# 14     15.27         4.0           RENT
# 15      6.03        10.0       MORTGAGE
# 16     11.71         1.0       MORTGAGE
# 17      6.03         6.0           RENT
# 18     12.42        10.0           RENT
# 19     11.71        10.0            OWN

# %%
#Truy xuất 100 dòng dữ liệu đầu tiên,
#của các cột có index 0, 4, 6, 7
df_loan.iloc[:100,[0,4,6,7]]
# Out:
#     loan_amnt home_ownership             purpose addr_state
# 0        5000           RENT         credit_card         AZ
# 1        2500           RENT                 car         GA
# 2        2400           RENT      small_business         IL
# 3       10000           RENT               other         CA
# 4        5000           RENT             wedding         AZ
# ..        ...            ...                 ...        ...
# 95      24000           RENT  debt_consolidation         CA
# 96       6000           RENT  debt_consolidation         CA
# 97       6000           RENT  debt_consolidation         AZ
# 98       2100       MORTGAGE            vacation         LA
# 99       5500       MORTGAGE      small_business         CT
#
# [100 rows x 4 columns]

# %%
df_loan.iloc[:10,:]
# Out:
#    loan_amnt       term  int_rate  emp_length home_ownership  annual_inc  \
# 0       5000  36 months     10.65        10.0           RENT     24000.0
# 1       2500  60 months     15.27         0.0           RENT     30000.0
# 2       2400  36 months     15.96        10.0           RENT     12252.0
# 3      10000  36 months     13.49        10.0           RENT     49200.0
# 4       5000  36 months      7.90         3.0           RENT     36000.0
# 5       3000  36 months     18.64         9.0           RENT     48000.0
# 6       5600  60 months     21.28         4.0            OWN     40000.0
# 7       5375  60 months     12.69         0.0           RENT     15000.0
# 8       6500  60 months     14.65         5.0            OWN     72000.0
# 9      12000  36 months     12.69        10.0            OWN     75000.0
#
#               purpose addr_state    dti  delinq_2yrs  revol_util  total_acc  \
# 0         credit_card         AZ  27.65          0.0        83.7        9.0
# 1                 car         GA   1.00          0.0         9.4        4.0
# 2      small_business         IL   8.72          0.0        98.5       10.0
# 3               other         CA  20.00          0.0        21.0       37.0
# 4             wedding         AZ  11.20          0.0        28.3       12.0
# 5                 car         CA   5.35          0.0        87.5        4.0
# 6      small_business         CA   5.55          0.0        32.6       13.0
# 7               other         TX  18.08          0.0        36.5        3.0
# 8  debt_consolidation         AZ  16.12          0.0        20.6       23.0
# 9  debt_consolidation         CA  10.78          0.0        67.1       34.0
#
#    bad_loan  longest_credit_length verification_status
# 0         0                   26.0            verified
# 1         1                   12.0            verified
# 2         0                   10.0        not verified
# 3         0                   15.0            verified
# 4         0                    7.0            verified
# 5         0                    4.0            verified
# 6         1                    7.0            verified
# 7         1                    7.0            verified
# 8         0                   13.0        not verified
# 9         0                   22.0            verified

# %%
#Truy cập dòng dữ liệu 10, cột 7
df_loan.iloc[4,0]
# Out:
# 5000

# %%
#Truy cập dòng dữ liệu 10, dòng 7
#Cột dữ liệu 0, 1, 5
df_loan.iloc[[10,7],[0,1,5]]
# Out:
#     loan_amnt       term  annual_inc
# 10       9000  36 months     30000.0
# 7        5375  60 months     15000.0

# %%
df_loan.iloc[[12,4,2001],[0,1,2,6,7,12]]
# Out:
#       loan_amnt       term  int_rate      purpose addr_state  bad_loan
# 12        10000  36 months     10.65        other         CA         1
# 4          5000  36 months      7.90      wedding         AZ         0
# 2001      20000  36 months     13.49  credit_card         TX         0

# %% [markdown]
# #### df.loc[[index_row],[name_col]]: Truy cập tới dữ liệu của hàng và cột qua chỉ số index_row, tên cột name_col

# %%
#Truy cập từ dòng có index 20 đến dòng 25 của df
#chỉ lấy dữ liệu 4 cột: loan_amnt, home_ownership, purpose, addr_state
df_loan.loc[20:25,['loan_amnt','home_ownership','purpose','addr_state']]
# Out:
#     loan_amnt home_ownership             purpose addr_state
# 20      10000           RENT  debt_consolidation         CA
# 21       6000           RENT      major_purchase         CA
# 22      15000       MORTGAGE         credit_card         IL
# 23      15000           RENT  debt_consolidation         NY
# 24       5000           RENT               other         PA
# 25       4000       MORTGAGE  debt_consolidation         FL

# %% [markdown]
# # 4) Replacing Values and Renamde Columns
# ---
# ## 4.1) Replacing values

# %%
#tách lấy dataframe để thực hiện replacing values
df_new = df_loan.loc[:20,['loan_amnt',
                          'home_ownership',
                          'purpose',
                          'addr_state']]
df_new
# Out:
#     loan_amnt home_ownership             purpose addr_state
# 0        5000           RENT         credit_card         AZ
# 1        2500           RENT                 car         GA
# 2        2400           RENT      small_business         IL
# 3       10000           RENT               other         CA
# 4        5000           RENT             wedding         AZ
# 5        3000           RENT                 car         CA
# 6        5600            OWN      small_business         CA
# 7        5375           RENT               other         TX
# 8        6500            OWN  debt_consolidation         AZ
# 9       12000            OWN  debt_consolidation         CA
# 10       9000           RENT  debt_consolidation         VA
# 11       3000           RENT         credit_card         IL
# 12      10000           RENT               other         CA
# 13       1000           RENT  debt_consolidation         MO
# 14      10000           RENT    home_improvement         CA
# 15       3600       MORTGAGE      major_purchase         CT
# 16       6000       MORTGAGE             medical         UT
# 17       9200           RENT  debt_consolidation         CA
# 18      21000           RENT  debt_consolidation         FL
# 19      10000            OWN         credit_card         TX
# 20      10000           RENT  debt_consolidation         CA

# %%
#Thay thế giá trị purpose: credit_card--> wedding
#của index đầu tiên
df_new.loc[0,'purpose'] = 'wedding'
df_new
# Out:
#     loan_amnt home_ownership             purpose addr_state
# 0        5000           RENT             wedding         AZ
# 1        2500           RENT                 car         GA
# 2        2400           RENT      small_business         IL
# 3       10000           RENT               other         CA
# 4        5000           RENT             wedding         AZ
# 5        3000           RENT                 car         CA
# 6        5600            OWN      small_business         CA
# 7        5375           RENT               other         TX
# 8        6500            OWN  debt_consolidation         AZ
# 9       12000            OWN  debt_consolidation         CA
# 10       9000           RENT  debt_consolidation         VA
# 11       3000           RENT         credit_card         IL
# 12      10000           RENT               other         CA
# 13       1000           RENT  debt_consolidation         MO
# 14      10000           RENT    home_improvement         CA
# 15       3600       MORTGAGE      major_purchase         CT
# 16       6000       MORTGAGE             medical         UT
# 17       9200           RENT  debt_consolidation         CA
# 18      21000           RENT  debt_consolidation         FL
# 19      10000            OWN         credit_card         TX
# 20      10000           RENT  debt_consolidation         CA

# %%
#Thay thế giá trị thuộc tính loan_amnt: 2400 --> 8800
#của index = 2
df_new.iloc[2,0] = 8800
df_new
# Out:
#     loan_amnt home_ownership             purpose addr_state
# 0        5000           RENT             wedding         AZ
# 1        2500           RENT                 car         GA
# 2        8800           RENT      small_business         IL
# 3       10000           RENT               other         CA
# 4        5000           RENT             wedding         AZ
# 5        3000           RENT                 car         CA
# 6        5600            OWN      small_business         CA
# 7        5375           RENT               other         TX
# 8        6500            OWN  debt_consolidation         AZ
# 9       12000            OWN  debt_consolidation         CA
# 10       9000           RENT  debt_consolidation         VA
# 11       3000           RENT         credit_card         IL
# 12      10000           RENT               other         CA
# 13       1000           RENT  debt_consolidation         MO
# 14      10000           RENT    home_improvement         CA
# 15       3600       MORTGAGE      major_purchase         CT
# 16       6000       MORTGAGE             medical         UT
# 17       9200           RENT  debt_consolidation         CA
# 18      21000           RENT  debt_consolidation         FL
# 19      10000            OWN         credit_card         TX
# 20      10000           RENT  debt_consolidation         CA

# %%
#Thay thế nhiều giá trị trong DataFrame
#RENT --> MORTGAGE
#car --> small_business
df_new.replace({'RENT':'MORTGAGE',
                'car':'small_business'})
# Out:
#     loan_amnt home_ownership             purpose addr_state
# 0        5000       MORTGAGE             wedding         AZ
# 1        2500       MORTGAGE      small_business         GA
# 2        8800       MORTGAGE      small_business         IL
# 3       10000       MORTGAGE               other         CA
# 4        5000       MORTGAGE             wedding         AZ
# 5        3000       MORTGAGE      small_business         CA
# 6        5600            OWN      small_business         CA
# 7        5375       MORTGAGE               other         TX
# 8        6500            OWN  debt_consolidation         AZ
# 9       12000            OWN  debt_consolidation         CA
# 10       9000       MORTGAGE  debt_consolidation         VA
# 11       3000       MORTGAGE         credit_card         IL
# 12      10000       MORTGAGE               other         CA
# 13       1000       MORTGAGE  debt_consolidation         MO
# 14      10000       MORTGAGE    home_improvement         CA
# 15       3600       MORTGAGE      major_purchase         CT
# 16       6000       MORTGAGE             medical         UT
# 17       9200       MORTGAGE  debt_consolidation         CA
# 18      21000       MORTGAGE  debt_consolidation         FL
# 19      10000            OWN         credit_card         TX
# 20      10000       MORTGAGE  debt_consolidation         CA

# %%
df_new
# Out:
#     loan_amnt home_ownership             purpose addr_state
# 0        5000           RENT             wedding         AZ
# 1        2500           RENT                 car         GA
# 2        8800           RENT      small_business         IL
# 3       10000           RENT               other         CA
# 4        5000           RENT             wedding         AZ
# 5        3000           RENT                 car         CA
# 6        5600            OWN      small_business         CA
# 7        5375           RENT               other         TX
# 8        6500            OWN  debt_consolidation         AZ
# 9       12000            OWN  debt_consolidation         CA
# 10       9000           RENT  debt_consolidation         VA
# 11       3000           RENT         credit_card         IL
# 12      10000           RENT               other         CA
# 13       1000           RENT  debt_consolidation         MO
# 14      10000           RENT    home_improvement         CA
# 15       3600       MORTGAGE      major_purchase         CT
# 16       6000       MORTGAGE             medical         UT
# 17       9200           RENT  debt_consolidation         CA
# 18      21000           RENT  debt_consolidation         FL
# 19      10000            OWN         credit_card         TX
# 20      10000           RENT  debt_consolidation         CA

# %%
#Khi muốn thay đổi áp dụng lên DataFrame hiện tại
#Thiết lập tham số inplace=True
df_new.replace({'RENT':'MORTGAGE',
                'car':'small_business'}, inplace=True)
df_new
# Out:
#     loan_amnt home_ownership             purpose addr_state
# 0        5000       MORTGAGE             wedding         AZ
# 1        2500       MORTGAGE      small_business         GA
# 2        8800       MORTGAGE      small_business         IL
# 3       10000       MORTGAGE               other         CA
# 4        5000       MORTGAGE             wedding         AZ
# 5        3000       MORTGAGE      small_business         CA
# 6        5600            OWN      small_business         CA
# 7        5375       MORTGAGE               other         TX
# 8        6500            OWN  debt_consolidation         AZ
# 9       12000            OWN  debt_consolidation         CA
# 10       9000       MORTGAGE  debt_consolidation         VA
# 11       3000       MORTGAGE         credit_card         IL
# 12      10000       MORTGAGE               other         CA
# 13       1000       MORTGAGE  debt_consolidation         MO
# 14      10000       MORTGAGE    home_improvement         CA
# 15       3600       MORTGAGE      major_purchase         CT
# 16       6000       MORTGAGE             medical         UT
# 17       9200       MORTGAGE  debt_consolidation         CA
# 18      21000       MORTGAGE  debt_consolidation         FL
# 19      10000            OWN         credit_card         TX
# 20      10000       MORTGAGE  debt_consolidation         CA

# %%
df_new.replace({5000:8000}, inplace=True)
df_new

# %%
#Thay thế tên viết tắt bằng tên đầy đủ.
state_name={'AZ':'Arizona',
            'GA':'Georgia',
            'IL':'Illinois',
            'CA':'California',
            'TX':'Texas',
            'VA':'Virgrinia'}
#Trong cột addr_state
df_new['addr_state'].replace(state_name,inplace=True)
df_new
# Out:
#     loan_amnt home_ownership             purpose  addr_state
# 0        5000       MORTGAGE             wedding     Arizona
# 1        2500       MORTGAGE      small_business     Georgia
# 2        8800       MORTGAGE      small_business    Illinois
# 3       10000       MORTGAGE               other  California
# 4        5000       MORTGAGE             wedding     Arizona
# 5        3000       MORTGAGE      small_business  California
# 6        5600            OWN      small_business  California
# 7        5375       MORTGAGE               other       Texas
# 8        6500            OWN  debt_consolidation     Arizona
# 9       12000            OWN  debt_consolidation  California
# 10       9000       MORTGAGE  debt_consolidation   Virgrinia
# 11       3000       MORTGAGE         credit_card    Illinois
# 12      10000       MORTGAGE               other  California
# 13       1000       MORTGAGE  debt_consolidation          MO
# 14      10000       MORTGAGE    home_improvement  California
# 15       3600       MORTGAGE      major_purchase          CT
# 16       6000       MORTGAGE             medical          UT
# 17       9200       MORTGAGE  debt_consolidation  California
# 18      21000       MORTGAGE  debt_consolidation          FL
# 19      10000            OWN         credit_card       Texas
# 20      10000       MORTGAGE  debt_consolidation  California

# %% [markdown]
# ## 4.2) Thay đổi tên cột trong DataFrame
# ---

# %%
df_new = df_loan[['loan_amnt','home_ownership','purpose','addr_state']].copy()
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163987 entries, 0 to 163986
# Data columns (total 4 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   loan_amnt       163987 non-null  int64
#  1   home_ownership  163987 non-null  object
#  2   purpose         163987 non-null  object
#  3   addr_state      163987 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 5.0+ MB

# %%
#Đổi tên cột
t = df_new.rename(columns={'loan_amnt':'Số tiền vay',
                       'home_ownership':'Tình trạng nhà ở',
                       'purpose': ' Mục đích vay tiền',
                       'addr_state':'Địa chỉ'})
t.head()
# Out:
#    Số tiền vay Tình trạng nhà ở  Mục đích vay tiền Địa chỉ
# 0         5000             RENT        credit_card      AZ
# 1         2500             RENT                car      GA
# 2         2400             RENT     small_business      IL
# 3        10000             RENT              other      CA
# 4         5000             RENT            wedding      AZ

# %%
#Muốn áp dụng thay đổi vào trực tiếp biến df, sử dụng inplace=True
df_new.rename(columns={'loan_amnt':'Số tiền vay',
                       'home_ownership':'Tình trạng nhà ở',
                       'purpose': ' Mục đích vay tiền',
                       'addr_state':'Địa chỉ'}, inplace=True)
df_new.head()

# %%
#Đổi tên cột sang viết hoa
df_new.rename(str.upper, axis='columns')
# Out:
#         LOAN_AMNT HOME_OWNERSHIP             PURPOSE ADDR_STATE
# 0            5000           RENT         credit_card         AZ
# 1            2500           RENT                 car         GA
# 2            2400           RENT      small_business         IL
# 3           10000           RENT               other         CA
# 4            5000           RENT             wedding         AZ
# ...           ...            ...                 ...        ...
# 163982      15000       MORTGAGE         credit_card         OK
# 163983      20000            OWN    home_improvement         VA
# 163984      12825       MORTGAGE  debt_consolidation         TX
# 163985      27650           RENT         credit_card         NY
# 163986      17000       MORTGAGE  debt_consolidation         PA
#
# [163987 rows x 4 columns]

# %%
df_new

# %% [markdown]
# ## Bài tập 24:
# ---

# %% [markdown]
# ## 5) Filter Data
# ---

# %%
#Đọc dữ liệu
import pandas as pd
path = 'Data_Excercise/csv_Data_BMI.csv'
df_bmi = pd.read_csv(path)
df_bmi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Personal   500 non-null    object
#  1   Gender     500 non-null    object
#  2   Height_cm  500 non-null    int64
#  3   Weight_kg  500 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 15.8+ KB

# %%
df_bmi.head()
# Out:
#   Personal  Gender  Height_cm  Weight_kg
# 0       P1    Male        174         96
# 1       P2    Male        189         87
# 2       P3  Female        185        110
# 3       P4  Female        195        104
# 4       P5    Male        149         61

# %%
#lọc danh sách người giới tính nam
#Cách 1:
df_male1 = df_bmi[df_bmi.Gender=='Male']
df_male1.head()
# Out:
#   Personal Gender  Height_cm  Weight_kg
# 0       P1   Male        174         96
# 1       P2   Male        189         87
# 4       P5   Male        149         61
# 5       P6   Male        189        104
# 6       P7   Male        147         92

# %%
df_male1.info()

# %%
#Cách 2: sử dụng phương thức query
df_male2 = df_bmi.query('Gender=="Male"')
df_male2.head()

# %%
#Cách 3: sử dụng loc
df_male3 = df_bmi.loc[(df_bmi.Gender=="Male")]
df_male3.head()
# Out:
#   Personal Gender  Height_cm  Weight_kg
# 0       P1   Male        174         96
# 1       P2   Male        189         87
# 4       P5   Male        149         61
# 5       P6   Male        189        104
# 6       P7   Male        147         92

# %%
#Kết hợp nhiều tiêu chí lọc dữ liệu
#lọc người có giới tính Femal và cân nặng dưới 70kg
df_p1 = df_bmi[(df_bmi.Gender =='Female') & (df_bmi.Weight_kg<70)]
df_p1
# Out:
#     Personal  Gender  Height_cm  Weight_kg
# 24       P25  Female        172         67
# 25       P26  Female        151         64
# 32       P33  Female        195         65
# 51       P52  Female        176         54
# 60       P61  Female        191         54
# 67       P68  Female        168         59
# 70       P71  Female        153         51
# 99      P100  Female        190         50
# 116     P117  Female        165         57
# 140     P141  Female        169         54
# 150     P151  Female        196         50
# 152     P153  Female        150         60
# 168     P169  Female        151         67
# 209     P210  Female        148         67
# 214     P215  Female        185         52
# 238     P239  Female        174         65
# 244     P245  Female        183         50
# 255     P256  Female        162         58
# 263     P264  Female        157         52
# 273     P274  Female        163         57
# 288     P289  Female        156         52
# 292     P293  Female        162         68
# 313     P314  Female        179         67
# 314     P315  Female        180         60
# 324     P325  Female        144         66
# 325     P326  Female        148         54
# 333     P334  Female        172         62
# 334     P335  Female        157         56
# 346     P347  Female        191         68
# 349     P350  Female        157         60
# 352     P353  Female        160         51
# 358     P359  Female        180         58
# 360     P361  Female        193         61
# 369     P370  Female        147         67
# 373     P374  Female        163         63
# 388     P389  Female        157         66
# 389     P390  Female        150         50
# 390     P391  Female        167         58
# 398     P399  Female        149         61
# 417     P418  Female        162         64
# 419     P420  Female        177         61
# 420     P421  Female        195         61
# 425     P426  Female        180         59
# 472     P473  Female        178         65
# 478     P479  Female        151         55
# 490     P491  Female        164         59
# 492     P493  Female        198         50
# 493     P494  Female        170         53

# %%
#Kết hợp nhiều tiêu chí lọc dữ liệu
#lọc người có chiều cao > 195 cm hoặc cân nặng > 150kg
df_p2 = df_bmi[(df_bmi.Height_cm >195) & (df_bmi.Weight_kg<70)]
df_p2
# Out:
#     Personal  Gender  Height_cm  Weight_kg
# 85       P86    Male        198         50
# 150     P151  Female        196         50
# 308     P309    Male        196         69
# 492     P493  Female        198         50

# %%
# toán tử ~ - Not
df_p3 = df_bmi[~(df_bmi.Weight_kg<155)]
df_p3

# %%
#Lọc ra những người có cân nặng bằng 150, 155 và 160kg
# phương thức isin (tương tự như in)
df_p4 = df_bmi[df_bmi.Weight_kg.isin([150,155,160])]
df_p4
# Out:
#     Personal  Gender  Height_cm  Weight_kg
# 102     P103    Male        161        155
# 106     P107    Male        166        160
# 123     P124  Female        184        160
# 134     P135  Female        171        155
# 135     P136  Female        183        150
# 157     P158    Male        168        160
# 204     P205    Male        145        160
# 211     P212    Male        148        155
# 237     P238    Male        165        155
# 243     P244  Female        177        155
# 287     P288    Male        178        160
# 330     P331  Female        164        160
# 489     P490  Female        179        150

# %%
df_bmi[df_bmi.Weight_kg.isin([150,155,160])].count()
# Out:
# Personal     13
# Gender       13
# Height_cm    13
# Weight_kg    13
# dtype: int64

# %% [markdown]
# ## 6) Đặc trưng thống kê
# ---

# %%
#Tính tổng theo cột chiều cao
df_bmi['Weight_kg'].sum()
# Out:
# 53000

# %%
#Tính tổng trong toàn bộ DataFrame
df_bmi.sum()
# Out:
# Personal     P1P2P3P4P5P6P7P8P9P10P11P12P13P14P15P16P17P18P...
# Gender       MaleMaleFemaleFemaleMaleMaleMaleMaleMaleFemale...
# Height_cm                                                84972
# Weight_kg                                                53000
# dtype: object

# %%
#tìm Max, Min của thuộc tính cân nặng
w_max = df_bmi['Weight_kg'].max()
w_min = df_bmi['Weight_kg'].min()
print('Cân nặng lớn nhất:',w_max, '(kg)')
print('Cân nặng nhỏ nhất:',w_min, '(kg)')
# Out:
# Cân nặng lớn nhất: 160 (kg)
# Cân nặng nhỏ nhất: 50 (kg)

# %%
#tìm Max, Min của thuộc tính chieu cao
w_max = df_bmi['Height_cm'].max()
w_min = df_bmi['Height_cm'].min()
print('Chiều cao lớn nhất:',w_max, '(cm)')
print('Chiều cao nhỏ nhất:',w_min, '(cm)')
# Out:
# Chiều cao lớn nhất: 199 (cm)
# Chiều cao nhỏ nhất: 140 (cm)

# %%
#cộng dồn giá trị các phần tử theo hàng
df_bmi['Weight_kg'].cumsum()
# df_bmi[['Weight_kg']]
# Out:
# 0         96
# 1        183
# 2        293
# 3        397
# 4        458
#        ...
# 495    52517
# 496    52638
# 497    52774
# 498    52869
# 499    53000
# Name: Weight_kg, Length: 500, dtype: int64

# %%
#tìm Mean, Median
w_mean = df_bmi['Weight_kg'].mean()
w_median = df_bmi['Weight_kg'].median()
print('Cân nặng trung bình:',w_mean, '(kg)')
print('trung vị:',w_median, '(kg)')

# %%
#tìm Mean, Median của chiều cao
h_mean = df_bmi['Height_cm'].mean()
h_median = df_bmi['Height_cm'].median()
print('Chiều cao trung bình:',h_mean, '(cm)')
print('Trung vị:',h_median, '(cm)')

# %%
#tìm độ lệch chuẩn của chiều cao, cân nặng
h_std = df_bmi['Height_cm'].std()
w_std = df_bmi['Weight_kg'].std()
print('sdt của chiều cao:', h_std)
print('sdt của cân nặng:', w_std)
# Out:
# sdt của chiều cao: 16.37526067959376
# sdt của cân nặng: 32.38260746964435

# %% [markdown]
# ## 7) Unique
# ---

# %%
#Xác định giá trị duy nhất trong một cột
df_bmi['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
#Thống kê số lượng theo giá trị duy nhất
unique_gender = df_bmi['Gender'].value_counts()
unique_gender
# Out:
# Female    255
# Male      245
# Name: Gender, dtype: int64

# %%
#Vẽ đồ thị thể hiện kết quả 
plt.bar(unique_gender.index, unique_gender.values)
plt.grid(True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-6d802f8a3b7b> in <module>
#       1 #Vẽ đồ thị thể hiện kết quả
# ----> 2 plt.bar(unique_gender.index, unique_gender.values)
#       3 plt.grid(True)
#
# NameError: name 'plt' is not defined

# %%
#Thống kê theo cân nặng
unique_weight = df_bmi['Weight_kg'].value_counts()
unique_weight
# Out:
# 80     9
# 104    9
# 50     9
# 96     8
# 70     8
#       ..
# 91     1
# 63     1
# 93     1
# 134    1
# 53     1
# Name: Weight_kg, Length: 110, dtype: int64

# %%
type(unique_weight)
# Out:
# pandas.core.series.Series

# %%
plt.bar(unique_weight.index,unique_weight.values)

# %% [markdown]
# # Bài tập 25:
# ---

# %% [markdown]
# ## 9. Phát hiện và xử lý missing data
# ---
# * Vì nhiều lý do, dữ liệu có thể bị lỗi hoặc bị thiếu ở một số vị trí của một số feature.
#
# * Hầu hết các thuật toán học máy không xử lý với dữ liệu bị thiếu, do đó cần phải được xử lý ở bước tiền xử lý dữ liệu.
#
# ### A) Phát hiện missing data
# ---

# %%
#Đọc file dữ liệu chứa missing
#Khai báo sử dụng thư viện Pandas
import pandas as pd
#Xác định đường dẫn tới file dữ liệu missing
path ='Data_Excercise/Data_Temp_missing.csv'
#Đọc file dữ liệu csv với pandas
data_temp = pd.read_csv(path)
data_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   time         24 non-null     object
#  1   Ha Noi       22 non-null     float64
#  2   Vinh         22 non-null     float64
#  3   Da Nang      22 non-null     float64
#  4   Nha Trang    21 non-null     float64
#  5   Ho Chi Minh  24 non-null     float64
#  6   Ca Mau       24 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 1.4+ KB

# %%
data_temp
# Out:
#             time  Ha Noi   Vinh  Da Nang  Nha Trang  Ho Chi Minh  Ca Mau
# 0   00 15-9-2019   25.65  24.79    24.01      25.06        25.48   24.97
# 1   01 15-9-2019     NaN  24.21    24.02      24.93        25.16   24.83
# 2   02 15-9-2019   25.05  23.73    23.89      24.79        24.80   24.55
# 3   03 15-9-2019   24.79  23.36    23.83        NaN        24.74   24.48
# 4   04 15-9-2019   24.59  23.05    23.69      24.82        24.80   24.38
# 5   05 15-9-2019   24.40    NaN    23.52      24.79        24.87   24.40
# 6   06 15-9-2019   24.38  22.79    23.68      25.10        24.71   24.41
# 7   07 15-9-2019   26.72  25.61    24.92      26.56        25.03   24.91
# 8   08 15-9-2019   28.84  26.93    26.51      26.53        25.75   25.85
# 9   09 15-9-2019   30.29  28.72    27.48      26.95        26.64   26.79
# 10  10 15-9-2019     NaN  29.97      NaN        NaN        27.68   27.53
# 11  11 15-9-2019   32.05  28.93    26.86      27.38        28.43   28.98
# 12  12 15-9-2019   31.31  28.94    26.65      27.47        28.29   29.24
# 13  13 15-9-2019   30.95    NaN    27.83      27.44        28.00   30.66
# 14  14 15-9-2019   30.56  30.62    26.49      27.16        27.67   30.97
# 15  15 15-9-2019   31.13  30.58    26.29      26.68        27.29   30.59
# 16  16 15-9-2019   30.80  30.20      NaN      26.45        27.29   29.13
# 17  17 15-9-2019   29.94  29.36    25.80      26.67        26.69   28.72
# 18  18 15-9-2019   28.53  27.48    24.82      25.92        25.81   27.46
# 19  19 15-9-2019   28.89  27.03    24.93      25.88        25.93   27.07
# 20  20 15-9-2019   28.06  26.41    24.70        NaN        25.97   26.75
# 21  21 15-9-2019   27.43  26.20    24.41      25.62        25.94   26.32
# 22  22 15-9-2019   26.98  25.79    24.17      25.60        25.90   26.29
# 23  23 15-9-2019   26.68  25.31    23.81      25.53        25.80   26.36

# %%
#Thống kê số liệu missing trong Data frame
#Theo từng cột
print('Số lượng missing data trong file dữ liệu:')
print(data_temp.isnull().sum())
# Out:
# Số lượng missing data trong file dữ liệu:
# time           0
# Ha Noi         2
# Vinh           2
# Da Nang        2
# Nha Trang      3
# Ho Chi Minh    0
# Ca Mau         0
# dtype: int64

# %%
#Xây dựng hàm thống kê dữ liệu missing trong dataframe:
#-----------------------------------------------------
#Đầu vào của hàm là 1 biến Dataframe
#Đầu ra bao gồm các thông số:
#Tổng số cột của file dữ liệu
#Tổng số cột có chứa dữ liệu missing
#Danh sách các cột chứa dữ liệu missing với 2 thống số:
#Tổng số giá trị missing tương ứng với cột đó
#Tỷ lệ % dữ liệu missing trên tổng số dữ liệu của cột
def missing_values(df):
        mis_val = df.isnull().sum()
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Số giá trị Missing', 1 : 'Tỷ lệ % missing'})
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        'Tỷ lệ % missing', ascending=False).round(1)
        print ("File dữ liệu bao gồm có: " + str(df.shape[1]) + " cột.\n"      
            "Có " + str(mis_val_table_ren_columns.shape[0]) +
              " cột chứa missing values.")
        return mis_val_table_ren_columns

#Check dữ liệu missing trong DataFrame: data_temp
missing_values(data_temp)
# Out:
# File dữ liệu bao gồm có: 7 cột.
# Có 4 cột chứa missing values.
#            Số giá trị Missing  Tỷ lệ % missing
# Nha Trang                   3             12.5
# Ha Noi                      2              8.3
# Vinh                        2              8.3
# Da Nang                     2              8.3

# %%
# mis_val_percent = 100 * data_temp.isnull().sum() / len(data_temp)

# mis_val_percent
mis_val = data_temp.isnull().sum()
mis_val_percent = 100 * data_temp.isnull().sum() / len(data_temp)
mis_val_table = pd.concat([mis_val, mis_val_percent],axis=1)
mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Số giá trị Missing', 1 : 'Tỷ lệ % missing'})
mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,0] != 0].sort_values(
        'Tỷ lệ % missing', ascending=False).round(1)
mis_val_table_ren_columns
# Out:
#            Số giá trị Missing  Tỷ lệ % missing
# Nha Trang                   3             12.5
# Ha Noi                      2              8.3
# Vinh                        2              8.3
# Da Nang                     2              8.3

# %%
#  len(data_temp)

df_loan = pd.read_csv('Data_Excercise\csv_Data_Loan.csv')
df_loan.info()
# missing_values(df_loan)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163987 entries, 0 to 163986
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   loan_amnt              163987 non-null  int64
#  1   term                   163987 non-null  object
#  2   int_rate               163987 non-null  float64
#  3   emp_length             158183 non-null  float64
#  4   home_ownership         163987 non-null  object
#  5   annual_inc             163983 non-null  float64
#  6   purpose                163987 non-null  object
#  7   addr_state             163987 non-null  object
#  8   dti                    163987 non-null  float64
#  9   delinq_2yrs            163958 non-null  float64
#  10  revol_util             163794 non-null  float64
#  11  total_acc              163958 non-null  float64
#  12  bad_loan               163987 non-null  int64
#  13  longest_credit_length  163958 non-null  float64
#  14  verification_status    163987 non-null  object
# dtypes: float64(8), int64(2), object(5)
# memory usage: 18.8+ MB

# %%
#Trực quan hóa dữ liệu
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(0,24)
plt.rcParams["figure.figsize"] = (12,5)
data_temp.iloc[:,1:5].plot(style='-o')
plt.xticks(x)
plt.xlabel('Thời gian (h)')
plt.ylabel('Nhiệt độ (oC)')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4280f260ab46> in <module>
#       4 x = np.arange(0,24)
#       5 plt.rcParams["figure.figsize"] = (12,5)
# ----> 6 data_temp.iloc[:,1:5].plot(style='-o')
#       7 plt.xticks(x)
#       8 plt.xlabel('Thời gian (h)')
#
# NameError: name 'data_temp' is not defined

# %%
#Liệt kê các dòng dữ liệu missing 
#1. Liệt kê theo từng features:
data_temp[pd.isnull(data_temp['Ha Noi'])]
# Out:
#             time  Ha Noi   Vinh  Da Nang  Nha Trang  Ho Chi Minh  Ca Mau
# 1   01 15-9-2019     NaN  24.21    24.02      24.93        25.16   24.83
# 10  10 15-9-2019     NaN  29.97      NaN        NaN        27.68   27.53

# %%
data_temp[pd.isnull(data_temp['Nha Trang'])]

# %%
#BAI NAY TEST
df_loan[pd.isnull(df_loan['annual_inc'])]
# Out:
#        loan_amnt       term  int_rate  emp_length home_ownership  annual_inc  \
# 38948       5000  36 months      7.43         0.0           NONE         NaN
# 38949       7000  36 months      7.75         0.0           NONE         NaN
# 38979       6700  36 months      7.75         0.0           NONE         NaN
# 39032       6500  36 months      8.38         0.0           NONE         NaN
#
#       purpose addr_state  dti  delinq_2yrs  revol_util  total_acc  bad_loan  \
# 38948   other         NY  1.0          NaN         NaN        NaN         0
# 38949   other         NY  1.0          NaN         NaN        NaN         0
# 38979   other         NY  1.0          NaN         NaN        NaN         0
# 39032   other         NY  4.0          NaN         NaN        NaN         0
#
#        longest_credit_length verification_status
# 38948                    NaN        not verified
# 38949                    NaN        not verified
# 38979                    NaN        not verified
# 39032                    NaN        not verified

# %%
#2. Liệt kê các dòng missing của tất cả các features:
data_temp[data_temp.isnull().any(axis=1)]
# Out:
#             time  Ha Noi   Vinh  Da Nang  Nha Trang  Ho Chi Minh  Ca Mau
# 1   01 15-9-2019     NaN  24.21    24.02      24.93        25.16   24.83
# 3   03 15-9-2019   24.79  23.36    23.83        NaN        24.74   24.48
# 5   05 15-9-2019   24.40    NaN    23.52      24.79        24.87   24.40
# 10  10 15-9-2019     NaN  29.97      NaN        NaN        27.68   27.53
# 13  13 15-9-2019   30.95    NaN    27.83      27.44        28.00   30.66
# 16  16 15-9-2019   30.80  30.20      NaN      26.45        27.29   29.13
# 20  20 15-9-2019   28.06  26.41    24.70        NaN        25.97   26.75

# %% [markdown]
# ### B) Xử lý dữ liệu Missing
# ---
# Có 2 nhóm phương pháp được sử dụng để xử lý dữ liệu missing
# * Loại bỏ các dữ liệu missing (Row, Column)
# * Thay thế dữ liệu missing bằng giá trị khác
#
# <img src='pic/handling_missing.jpg' width='500px'>

# %%
data_temp

# %%
#1) Phương pháp 1:Loại bỏ các dữ liệu missing (Deletion)

#Xóa toàn bộ các hàng chứa missing data: axis=0 -> xóa hàng | how = any (all) chỉ cần hàng có feature chứa missing
data_new = data_temp.dropna(axis=0,how='any')
#Kết quả sau khi loại bỏ các row chứa missing
print(data_new)
# Out:
#             time  Ha Noi   Vinh  Da Nang  Nha Trang  Ho Chi Minh  Ca Mau
# 0   00 15-9-2019   25.65  24.79    24.01      25.06        25.48   24.97
# 2   02 15-9-2019   25.05  23.73    23.89      24.79        24.80   24.55
# 4   04 15-9-2019   24.59  23.05    23.69      24.82        24.80   24.38
# 6   06 15-9-2019   24.38  22.79    23.68      25.10        24.71   24.41
# 7   07 15-9-2019   26.72  25.61    24.92      26.56        25.03   24.91
# 8   08 15-9-2019   28.84  26.93    26.51      26.53        25.75   25.85
# 9   09 15-9-2019   30.29  28.72    27.48      26.95        26.64   26.79
# 11  11 15-9-2019   32.05  28.93    26.86      27.38        28.43   28.98
# 12  12 15-9-2019   31.31  28.94    26.65      27.47        28.29   29.24
# 14  14 15-9-2019   30.56  30.62    26.49      27.16        27.67   30.97
# 15  15 15-9-2019   31.13  30.58    26.29      26.68        27.29   30.59
# 17  17 15-9-2019   29.94  29.36    25.80      26.67        26.69   28.72
# 18  18 15-9-2019   28.53  27.48    24.82      25.92        25.81   27.46
# 19  19 15-9-2019   28.89  27.03    24.93      25.88        25.93   27.07
# 21  21 15-9-2019   27.43  26.20    24.41      25.62        25.94   26.32
# 22  22 15-9-2019   26.98  25.79    24.17      25.60        25.90   26.29
# 23  23 15-9-2019   26.68  25.31    23.81      25.53        25.80   26.36

# %%
#1) Phương pháp 1:Loại bỏ các dữ liệu missing (Deletion)

#Xóa toàn bộ các cột chứa missing data: axis=1 -> xóa cột
data_new = data_temp.dropna(axis=1,how='any')
#Kết quả sau khi loại bỏ các cột chứa missing
print(data_new)
# Out:
#             time  Ho Chi Minh  Ca Mau
# 0   00 15-9-2019        25.48   24.97
# 1   01 15-9-2019        25.16   24.83
# 2   02 15-9-2019        24.80   24.55
# 3   03 15-9-2019        24.74   24.48
# 4   04 15-9-2019        24.80   24.38
# 5   05 15-9-2019        24.87   24.40
# 6   06 15-9-2019        24.71   24.41
# 7   07 15-9-2019        25.03   24.91
# 8   08 15-9-2019        25.75   25.85
# 9   09 15-9-2019        26.64   26.79
# 10  10 15-9-2019        27.68   27.53
# 11  11 15-9-2019        28.43   28.98
# 12  12 15-9-2019        28.29   29.24
# 13  13 15-9-2019        28.00   30.66
# 14  14 15-9-2019        27.67   30.97
# 15  15 15-9-2019        27.29   30.59
# 16  16 15-9-2019        27.29   29.13
# 17  17 15-9-2019        26.69   28.72
# 18  18 15-9-2019        25.81   27.46
# 19  19 15-9-2019        25.93   27.07
# 20  20 15-9-2019        25.97   26.75
# 21  21 15-9-2019        25.94   26.32
# 22  22 15-9-2019        25.90   26.29
# 23  23 15-9-2019        25.80   26.36

# %%
#Dữ liệu gốc:
data_temp
# Out:
#             time  Ha Noi   Vinh  Da Nang  Nha Trang  Ho Chi Minh  Ca Mau
# 0   00 15-9-2019   25.65  24.79    24.01      25.06        25.48   24.97
# 1   01 15-9-2019     NaN  24.21    24.02      24.93        25.16   24.83
# 2   02 15-9-2019   25.05  23.73    23.89      24.79        24.80   24.55
# 3   03 15-9-2019   24.79  23.36    23.83        NaN        24.74   24.48
# 4   04 15-9-2019   24.59  23.05    23.69      24.82        24.80   24.38
# 5   05 15-9-2019   24.40    NaN    23.52      24.79        24.87   24.40
# 6   06 15-9-2019   24.38  22.79    23.68      25.10        24.71   24.41
# 7   07 15-9-2019   26.72  25.61    24.92      26.56        25.03   24.91
# 8   08 15-9-2019   28.84  26.93    26.51      26.53        25.75   25.85
# 9   09 15-9-2019   30.29  28.72    27.48      26.95        26.64   26.79
# 10  10 15-9-2019     NaN  29.97      NaN        NaN        27.68   27.53
# 11  11 15-9-2019   32.05  28.93    26.86      27.38        28.43   28.98
# 12  12 15-9-2019   31.31  28.94    26.65      27.47        28.29   29.24
# 13  13 15-9-2019   30.95    NaN    27.83      27.44        28.00   30.66
# 14  14 15-9-2019   30.56  30.62    26.49      27.16        27.67   30.97
# 15  15 15-9-2019   31.13  30.58    26.29      26.68        27.29   30.59
# 16  16 15-9-2019   30.80  30.20      NaN      26.45        27.29   29.13
# 17  17 15-9-2019   29.94  29.36    25.80      26.67        26.69   28.72
# 18  18 15-9-2019   28.53  27.48    24.82      25.92        25.81   27.46
# 19  19 15-9-2019   28.89  27.03    24.93      25.88        25.93   27.07
# 20  20 15-9-2019   28.06  26.41    24.70        NaN        25.97   26.75
# 21  21 15-9-2019   27.43  26.20    24.41      25.62        25.94   26.32
# 22  22 15-9-2019   26.98  25.79    24.17      25.60        25.90   26.29
# 23  23 15-9-2019   26.68  25.31    23.81      25.53        25.80   26.36

# %%
#PHƯƠNG PHÁP 2: Thay thế (Imputation)
#2.1) Thay thế các dữ liệu mất mát bằng một hằng số cố định
value = 25.0
#thay thế các giá trị missing bằng một giá trị cố định Value
data_new = data_temp.fillna(value)
print(data_new)
# Out:
#             time  Ha Noi   Vinh  Da Nang  Nha Trang  Ho Chi Minh  Ca Mau
# 0   00 15-9-2019   25.65  24.79    24.01      25.06        25.48   24.97
# 1   01 15-9-2019   25.00  24.21    24.02      24.93        25.16   24.83
# 2   02 15-9-2019   25.05  23.73    23.89      24.79        24.80   24.55
# 3   03 15-9-2019   24.79  23.36    23.83      25.00        24.74   24.48
# 4   04 15-9-2019   24.59  23.05    23.69      24.82        24.80   24.38
# 5   05 15-9-2019   24.40  25.00    23.52      24.79        24.87   24.40
# 6   06 15-9-2019   24.38  22.79    23.68      25.10        24.71   24.41
# 7   07 15-9-2019   26.72  25.61    24.92      26.56        25.03   24.91
# 8   08 15-9-2019   28.84  26.93    26.51      26.53        25.75   25.85
# 9   09 15-9-2019   30.29  28.72    27.48      26.95        26.64   26.79
# 10  10 15-9-2019   25.00  29.97    25.00      25.00        27.68   27.53
# 11  11 15-9-2019   32.05  28.93    26.86      27.38        28.43   28.98
# 12  12 15-9-2019   31.31  28.94    26.65      27.47        28.29   29.24
# 13  13 15-9-2019   30.95  25.00    27.83      27.44        28.00   30.66
# 14  14 15-9-2019   30.56  30.62    26.49      27.16        27.67   30.97
# 15  15 15-9-2019   31.13  30.58    26.29      26.68        27.29   30.59
# 16  16 15-9-2019   30.80  30.20    25.00      26.45        27.29   29.13
# 17  17 15-9-2019   29.94  29.36    25.80      26.67        26.69   28.72
# 18  18 15-9-2019   28.53  27.48    24.82      25.92        25.81   27.46
# 19  19 15-9-2019   28.89  27.03    24.93      25.88        25.93   27.07
# 20  20 15-9-2019   28.06  26.41    24.70      25.00        25.97   26.75
# 21  21 15-9-2019   27.43  26.20    24.41      25.62        25.94   26.32
# 22  22 15-9-2019   26.98  25.79    24.17      25.60        25.90   26.29
# 23  23 15-9-2019   26.68  25.31    23.81      25.53        25.80   26.36

# %%
#Sử dụng giá trị trung bình, trung vị để thay thế
data_temp.mean()

# %%
#PHƯƠNG PHÁP 2: Thay thế (Imputation)
#2.2)Thay thế các dữ liệu mất mát bằng giá trị liền trước của nó
data_new2 = data_temp.fillna(method='pad')
print(data_new2)
# Out:
#             time  Ha Noi   Vinh  Da Nang  Nha Trang  Ho Chi Minh  Ca Mau
# 0   00 15-9-2019   25.65  24.79    24.01      25.06        25.48   24.97
# 1   01 15-9-2019   25.65  24.21    24.02      24.93        25.16   24.83
# 2   02 15-9-2019   25.05  23.73    23.89      24.79        24.80   24.55
# 3   03 15-9-2019   24.79  23.36    23.83      24.79        24.74   24.48
# 4   04 15-9-2019   24.59  23.05    23.69      24.82        24.80   24.38
# 5   05 15-9-2019   24.40  23.05    23.52      24.79        24.87   24.40
# 6   06 15-9-2019   24.38  22.79    23.68      25.10        24.71   24.41
# 7   07 15-9-2019   26.72  25.61    24.92      26.56        25.03   24.91
# 8   08 15-9-2019   28.84  26.93    26.51      26.53        25.75   25.85
# 9   09 15-9-2019   30.29  28.72    27.48      26.95        26.64   26.79
# 10  10 15-9-2019   30.29  29.97    27.48      26.95        27.68   27.53
# 11  11 15-9-2019   32.05  28.93    26.86      27.38        28.43   28.98
# 12  12 15-9-2019   31.31  28.94    26.65      27.47        28.29   29.24
# 13  13 15-9-2019   30.95  28.94    27.83      27.44        28.00   30.66
# 14  14 15-9-2019   30.56  30.62    26.49      27.16        27.67   30.97
# 15  15 15-9-2019   31.13  30.58    26.29      26.68        27.29   30.59
# 16  16 15-9-2019   30.80  30.20    26.29      26.45        27.29   29.13
# 17  17 15-9-2019   29.94  29.36    25.80      26.67        26.69   28.72
# 18  18 15-9-2019   28.53  27.48    24.82      25.92        25.81   27.46
# 19  19 15-9-2019   28.89  27.03    24.93      25.88        25.93   27.07
# 20  20 15-9-2019   28.06  26.41    24.70      25.88        25.97   26.75
# 21  21 15-9-2019   27.43  26.20    24.41      25.62        25.94   26.32
# 22  22 15-9-2019   26.98  25.79    24.17      25.60        25.90   26.29
# 23  23 15-9-2019   26.68  25.31    23.81      25.53        25.80   26.36

# %%
#PHƯƠNG PHÁP 2: Thay thế (Imputation)
#2.3)Thay thế các dữ liệu mất mát bằng giá trị liền sau của nó
data_new3 = data_temp.fillna(method='bfill')
print(data_new3)

# %%
#PHƯƠNG PHÁP 2: Thay thế (Imputation)
#2.4)Thay thế bằng giá trị trung bình
#Sử dụng hàm interpolate để thay thế giá trị missing với tham số:
#Thuật toán nội suy: Tuyến tính (linear)
#Hướng nội suy: Tiến lên (forward)
data_new4 = data_temp.interpolate(method='linear', limit_direction ='forward')
print(data_new4)
# Out:
#             time  Ha Noi   Vinh  Da Nang  Nha Trang  Ho Chi Minh  Ca Mau
# 0   00 15-9-2019   25.65  24.79   24.010     25.060        25.48   24.97
# 1   01 15-9-2019   25.35  24.21   24.020     24.930        25.16   24.83
# 2   02 15-9-2019   25.05  23.73   23.890     24.790        24.80   24.55
# 3   03 15-9-2019   24.79  23.36   23.830     24.805        24.74   24.48
# 4   04 15-9-2019   24.59  23.05   23.690     24.820        24.80   24.38
# 5   05 15-9-2019   24.40  22.92   23.520     24.790        24.87   24.40
# 6   06 15-9-2019   24.38  22.79   23.680     25.100        24.71   24.41
# 7   07 15-9-2019   26.72  25.61   24.920     26.560        25.03   24.91
# 8   08 15-9-2019   28.84  26.93   26.510     26.530        25.75   25.85
# 9   09 15-9-2019   30.29  28.72   27.480     26.950        26.64   26.79
# 10  10 15-9-2019   31.17  29.97   27.170     27.165        27.68   27.53
# 11  11 15-9-2019   32.05  28.93   26.860     27.380        28.43   28.98
# 12  12 15-9-2019   31.31  28.94   26.650     27.470        28.29   29.24
# 13  13 15-9-2019   30.95  29.78   27.830     27.440        28.00   30.66
# 14  14 15-9-2019   30.56  30.62   26.490     27.160        27.67   30.97
# 15  15 15-9-2019   31.13  30.58   26.290     26.680        27.29   30.59
# 16  16 15-9-2019   30.80  30.20   26.045     26.450        27.29   29.13
# 17  17 15-9-2019   29.94  29.36   25.800     26.670        26.69   28.72
# 18  18 15-9-2019   28.53  27.48   24.820     25.920        25.81   27.46
# 19  19 15-9-2019   28.89  27.03   24.930     25.880        25.93   27.07
# 20  20 15-9-2019   28.06  26.41   24.700     25.750        25.97   26.75
# 21  21 15-9-2019   27.43  26.20   24.410     25.620        25.94   26.32
# 22  22 15-9-2019   26.98  25.79   24.170     25.600        25.90   26.29
# 23  23 15-9-2019   26.68  25.31   23.810     25.530        25.80   26.36

# %% [markdown]
# ## 10. Phát hiện và xử lý ngoại lai (Outliers)
# ---
# Một điểm ngoại lai là một điểm dữ liệu khác biệt đáng kể so với phần còn lại của tập dữ liệu. Ta thường xem các giá trị ngoại lai như là các mẫu dữ liệu đặc biệt, cách xa khỏi phần lớn dữ liệu khác trong tập dữ liệu
#
# * Hệ thống phát hiện xâm nhập (Intrusion detection systems)
# * Phát hiện gian lận tín dụng (Credit card fraud)
# * Trong chuẩn đoán y tế (Medical diagnosis)
# * Trong thực thi pháp luật (Law enforcement)
# * Trong khoa học trái đất (Earth science)
#
# <img src='pic/outliers.jpg'>
#
#
# ### a Phát hiện ngoại lai sử dụng biểu đồ
# ---
# <img src='pic/handling_outlier.jpg'>
#
#
# **1. Sử dụng biểu đồ Boxplot:**
#
# Biểu đồ Box-plot được sử dụng để đo khuynh hướng phân tán và xác định các giá trị ngoại lai của tập dữ liệu
# * Giá trị bé nhất (Minimum) của tập dữ liệu được xác định bằng Q1 – 1.5 * IQR;
# * Tứ phân vị thứ nhất (Q1) của tập dữ liệu
# * Tứ phân vị thứ hai (Q2) chính là giá trị trung vị (Median) của tập dữ liệu
# * Tứ phân vị thứ ba (Q3) của tập dữ liệu
# * Giá trị lớn nhất (Maximum) của tập dữ liệu có giá trị bằng Q3 + 1.5* IQR

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
#Đọc dữ liệu file
path_outlier = 'Data_Excercise/Data_Temp_Outlier.csv'
data_outlier = pd.read_csv(path_outlier)
data_outlier.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   time         24 non-null     object
#  1   Ha Noi       24 non-null     float64
#  2   Vinh         24 non-null     float64
#  3   Da Nang      24 non-null     float64
#  4   Nha Trang    24 non-null     float64
#  5   Ho Chi Minh  24 non-null     float64
#  6   Ca Mau       24 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 1.4+ KB

# %%
data_outlier

# %%
#Sử dụng biểu đồ Boxplot phát hiện ngoại lai
data_outlier.boxplot()
# Out:
# <AxesSubplot:>

# %%
#Sử dụng biểu đồ điểm
x = np.arange(0,24)
plt.rcParams["figure.figsize"] = (12,5)
data_outlier.loc[:,['Nha Trang','Ho Chi Minh']].plot(style='-o')
plt.xticks(x)
plt.xlabel('Thời gian (h)')
plt.ylabel('Nhiệt độ (oC)')
plt.grid(True)
plt.show()

#Nha trang: Ngoại lai trái (left outlier)
#TP Hồ Chí Minh: Ngoại lai phải (right outlier)

# %%
data_outlier[['Nha Trang']].boxplot()
# Out:
# <AxesSubplot:>

# %%
#Check dữ liệu của Nha Trang
data_outlier.loc[4:8,['Nha Trang']]
# Out:
#    Nha Trang
# 4      24.82
# 5      24.79
# 6       2.51
# 7      26.56
# 8      26.53

# %%
#Check dữ liệu của TP Hồ Chí Minh
data_outlier.loc[10:15,['Ho Chi Minh']]
# Out:
#     Ho Chi Minh
# 10        27.68
# 11        28.43
# 12        28.29
# 13        58.00
# 14        27.67
# 15        27.29

# %% [markdown]
# ### b) Xử lý outliers
# ---
#  Không có một phương pháp, cách thức xử lý ngoại lai chung nào áp dụng cho tất cả các bài toán, các kiểu dữ liệu khác nhau.Để lựa chọn được phương pháp phù hợp cần có những hiểu biết sâu sắc về tập dữ liệu, về bài toán đang giải quyết, có thể sử dụng chỉ một phương pháp xử lý ngoại lai và/hoặc kết hợp cả 3 nhóm phương pháp đã chỉ ra ở trên để xử lý ngoại lai cho cùng một tập dữ liệu.

# %%
#Tạo một bản sao dữ liệu
data_handling_outlier =data_outlier.copy()

# %%
#Với giá trị ngoại lai trạm Nha trang
#Xử lý bằng cách thay thế giá trị: 2.51 --> 25.1
x = np.arange(0,24)
plt.rcParams["figure.figsize"] = (10,3)
data_handling_outlier.loc[6,'Nha Trang'] = 25.10
data_handling_outlier[['Nha Trang']].plot(style='-*', color='red')
plt.xticks(x)
plt.xlabel('Thời gian (h)')
plt.ylabel('Nhiệt độ (oC)')
plt.grid(True)
plt.show()

# %%
#Với giá trị ngoại lai trạm Hồ Chí Minh
#Xử lý bằng cách chuyển về giá trị Null - Coi như giá trị missing
data_handling_outlier.loc[13,'Ho Chi Minh'] = np.NaN
data_handling_outlier[['Ho Chi Minh']].plot(style='-*', color='red')
plt.xticks(x)
plt.xlabel('Thời gian (h)')
plt.ylabel('Nhiệt độ (oC)')
plt.grid(True)
plt.show()

# %% [markdown]
# ### TRƯỜNG HỢP: Ngoại lai không phải là giá trị cực trị
# ---

# %%
#Check ngoại lai trạm Hà Nội
data_outlier[['Ha Noi']].plot(style='--d', color='green')
plt.xticks(x)
plt.xlabel('Thời gian (h)')
plt.ylabel('Nhiệt độ (oC)')
plt.grid(True)
# plt.grid(True)
print(data_outlier.loc[:10,['Ha Noi']])
# Out:
#     Ha Noi
# 0    25.65
# 1    25.31
# 2    25.05
# 3    24.79
# 4    24.59
# 5    30.80
# 6    24.38
# 7    26.72
# 8    28.84
# 9    30.29
# 10   31.35

# %%
#Sau khi xu ly gia tri ngoai lai
# data_outlier.loc[5,'Ha Noi'] = np.NaN
# data_outlier1 = data_outlier[['Ha Noi']].fillna(method ='pad')
# data_outlier1[['Ha Noi']].plot(style='--d', color='green')
# plt.xticks(x)
# plt.xlabel('Thời gian (h)')
# plt.ylabel('Nhiệt độ (oC)')
# plt.grid(True)
# plt.show()
# print(data_outlier1.loc[:10,['Ha Noi']])

# %% [markdown]
# ## Bài tập 26:
# ---
# * Đọc dữ liệu từ file Data_Patient.csv
# * Cho biết các cột chứa giá trị khuyết thiếu, xác định các vị trí thiếu dữ liệu và đề xuất phương án xử lý giá trị thiếu.
# * Phát hiện giá trị ngoại lai và xử lý trong dữ liệu (nếu có)

# %%
#{HỌC VIÊN VIẾT CODE XỬ LÝ Ở ĐÂY}
